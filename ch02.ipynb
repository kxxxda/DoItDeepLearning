# %%
# 파이썬 리스트
my_list = [10, 'hello list', 20]
print(my_list[1])
# Out:
# hello list

# %%
# 2x3 크기의 리스트(2개의 행과 3개의 열) 
my_list_2 = [[10, 20, 30], [40, 50, 60]]
print(my_list_2[1][1])
# Out:
# 50

# %%
import numpy as np

print(np.__version__)
# Out:
# 1.21.1

# %%
# 넘파이의 array 함수로 2차원 배열 만들기
my_arr = np.array([[10, 20, 30], [40, 50, 60]])
print(my_arr)
# Out:
# [[10 20 30]
#  [40 50 60]]

# %%
# type() 함수로 넘파이 배열인지 확인하기
type(my_arr)
# Out:
# numpy.ndarray

# %%
my_arr[0][2]
# Out:
# 30

# %%
# 넘파이 내장 함수 
np.sum(my_arr)
# Out:
# 210

# %%
# 맷플롯립 임포트 해주기
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3, 4, 5], [1, 4, 9, 16, 25]) # 찍힐 점들 !!
plt.show()

# %%
plt.scatter([1, 2, 3, 4, 5], [1, 4, 9, 16, 25])
plt.show()

# %%
x = np.random.randn(1000) # 표준 정규 분포를 따르는 난수 1,000개를 만듭니다.
y = np.random.randn(1000) # 표준 정규 분포를 따르는 난수 1,000개를 만듭니다.
plt.scatter(x, y)
plt.show()
